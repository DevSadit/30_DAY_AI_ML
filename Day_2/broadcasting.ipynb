# %%
import numpy as np

# %%
arr = np.array([2,3,4])
arr + 10
# Out:
# array([12, 13, 14])

# %%
arr = np.array([2,3,4])
arr * 10
# Out:
# array([20, 30, 40])

# %%
arr = np.array([2,3,4])
arr ** 2
# Out:
# array([ 4,  9, 16])
