# %%
import numpy as np

# %%
narray = np.array([10, 20, 30, 40, 50])
narray
# Out:
# array([10, 20, 30, 40, 50])

# %%
# accesing array with index
narray[2]
# Out:
# np.int64(30)

# %%
# accesing last element of array.
narray[-1]
# Out:
# np.int64(50)

# %%
# slice the array
# it start from the index which is indicated and stop before the 1 index. [start:stop:step]
narray[-1: -4: -1]
# Out:
# array([50, 40, 30])

# %%
# filter to find the numbers 
narray[narray <20]
# Out:
# array([10])
