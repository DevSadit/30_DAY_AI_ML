# %%
import numpy as np

# %%
          
# np.dot(A, B)
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
A = np.array([[1, 2],
              [3, 4]])

B = np.array([[5, 6],
              [7, 8]])

np.dot(A, B) # A @ B--> both are same
# Out:
# array([[19, 22],
#        [43, 50]])
