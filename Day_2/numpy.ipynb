# %%
import numpy as np

# %%
# making array
np.array([1, 6 ,6])
# Out:
# array([1, 6, 6])

# %%
# checking dimension with ndim
narray= np.array([1,2,3])
narray.ndim

narray_2= np.array([[[]]])
narray_2.ndim
# Out:
# 3

# %%
# range
range = np.arange(1, 10, 2) # ==> (start, stop, jump)
range
# Out:
# array([1, 3, 5, 7, 9])

# %%
# logspace: telling that (starting powers, ending powers, points)
logspace = np.logspace(1, 3, 3)
# logspace
logspace_2= np.logspace(2, 4, 2)
logspace_2
# Out:
# array([  100., 10000.])

# %%
# making matrix with zeros
zero= np.zeros([3, 2])
zero
# Out:
# array([[0., 0.],
#        [0., 0.],
#        [0., 0.]])

# %%
# ones
c = np.ones((3, 2))
c
# Out:
# array([[1., 1.],
#        [1., 1.],
#        [1., 1.]])

# %%
# random numbers
random = np.random.rand(3)
random
# Out:
# array([0.37747922, 0.03132812, 0.38420806])

# %%
# array size::-->> shape tells the size
narray = np.array([1,3,5])
narray.shape
# Out:
# (3,)
