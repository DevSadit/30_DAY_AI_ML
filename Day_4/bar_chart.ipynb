# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# to draw bar we use bar() function
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color="#4CAF50", width=0.1)
# Out:
# <BarContainer object of 4 artists>
