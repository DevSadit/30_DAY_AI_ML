# %%
import pandas as pd

# %%
fruit_protein = {
    "Guava": 2.6,
    "Avocado": 2.0,
    "Apricot": 1.4,
    "Blackberry": 1.4,
    "Banana": 1.1,
    "Kiwi": 1.1,
    "Cherry": 1.0,
    "Apple": 0.3
}

s_2 = pd.Series(fruit_protein, name="protein")
s_2
# Out:
# Guava         2.6
# Avocado       2.0
# Apricot       1.4
# Blackberry    1.4
# Banana        1.1
# Kiwi          1.1
# Cherry        1.0
# Apple         0.3
# Name: protein, dtype: float64

# %%
# logical operator (and or not)
# and
s_2[(s_2> 0.5) & (s_2 < 2)]
# Out:
# Apricot       1.4
# Blackberry    1.4
# Banana        1.1
# Kiwi          1.1
# Cherry        1.0
# Name: protein, dtype: float64

# %%
# or
s_2[(s_2>1 )| (s_2>2)]
# Out:
# Guava         2.6
# Avocado       2.0
# Apricot       1.4
# Blackberry    1.4
# Banana        1.1
# Kiwi          1.1
# Name: protein, dtype: float64
