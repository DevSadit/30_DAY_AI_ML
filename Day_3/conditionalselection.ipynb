# %%
import pandas as pd

# %%
fruit_protein = {
    "Guava": 2.6,
    "Avocado": 2.0,
    "Apricot": 1.4,
    "Blackberry": 1.4,
    "Banana": 1.1,
    "Kiwi": 1.1,
    "Cherry": 1.0,
    "Apple": 0.3
}

s_2 = pd.Series(fruit_protein, name="protein")
s_2
# Out:
# Guava         2.6
# Avocado       2.0
# Apricot       1.4
# Blackberry    1.4
# Banana        1.1
# Kiwi          1.1
# Cherry        1.0
# Apple         0.3
# Name: protein, dtype: float64

# %%
s_2>1
# Out:
# Guava          True
# Avocado        True
# Apricot        True
# Blackberry     True
# Banana         True
# Kiwi           True
# Cherry        False
# Apple         False
# Name: protein, dtype: bool
