# %%
import pandas as pd
import numpy as np

# %%
fruit_protein = {
    "Guava": 2.6,
    "Avocado": 2.0,
    "Apricot": 1.4,
    "Blackberry": 1.4,
    "Banana": 1.1,
    "Kiwi": 1.1,
    "Cherry": 1.0,
    "Apple": 0.3
}

s = pd.Series(fruit_protein, name="protein")
s
# Out:
# Guava         2.6
# Avocado       2.0
# Apricot       1.4
# Blackberry    1.4
# Banana        1.1
# Kiwi          1.1
# Cherry        1.0
# Apple         0.3
# Name: protein, dtype: float64

# %%
s["Kiwi"] = 5
s
# Out:
# Guava         2.6
# Avocado       2.0
# Apricot       1.4
# Blackberry    1.4
# Banana        1.1
# Kiwi          5.0
# Cherry        1.0
# Apple         0.3
# Name: protein, dtype: float64
